# %% [markdown]
# <a href="https://colab.research.google.com/github/lklmkv/tvp1t/blob/main/Missings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('MissingMigrants-Global-2019-12-31_correct.csv')
print(df.info())
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5987 entries, 0 to 5986
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Web ID                               5987 non-null   int64
#  1   Region of Incident                   5987 non-null   object
#  2   Reported Date                        5987 non-null   object
#  3   Reported Year                        5987 non-null   int64
#  4   Reported Month                       5987 non-null   object
#  5   Number Dead                          5762 non-null   float64
#  6   Minimum Estimated Number of Missing  576 non-null    float64
#  7   Total Dead and Missing               5987 non-null   int64
#  8   Number of Survivors                  914 non-null    float64
#  9   Number of Females                    1058 non-null   float64
#  10  Number of Males                      3286 non-null   float64
#  11  Number of Children                   753 non-null    float64
#  12  Cause of Death                       5987 non-null   object
#  13  Location Description                 5977 non-null   object
#  14  Information Source                   5985 non-null   object
#  15  Location Coordinates                 5986 non-null   object
#  16  Migration Route                      2931 non-null   object
#  17  URL                                  3810 non-null   object
#  18  UNSD Geographical Grouping           5941 non-null   object
#  19  Source Quality                       5987 non-null   int64
# dtypes: float64(6), int64(4), object(10)
# memory usage: 935.6+ KB
# None
#               Web ID Region of Incident   Reported Date  Reported Year  \
# count    5987.000000               5987            5987    5987.000000
# unique           NaN                 15            1756            NaN
# top              NaN   US-Mexico Border  March 20, 2016            NaN
# freq             NaN               1612              27            NaN
# mean    44220.795891                NaN             NaN    2016.912143
# std      5630.217519                NaN             NaN       1.377580
# min     30158.000000                NaN             NaN    2014.000000
# 25%     41043.500000                NaN             NaN    2016.000000
# 50%     43842.000000                NaN             NaN    2017.000000
# 75%     49262.500000                NaN             NaN    2018.000000
# max     52708.000000                NaN             NaN    2019.000000
#
#        Reported Month  Number Dead  Minimum Estimated Number of Missing  \
# count            5987  5762.000000                           576.000000
# unique             12          NaN                                  NaN
# top               Jun          NaN                                  NaN
# freq              607          NaN                                  NaN
# mean              NaN     3.208782                            26.776042
# std               NaN    13.037592                            64.005246
# min               NaN     0.000000                             0.000000
# 25%               NaN     1.000000                             2.000000
# 50%               NaN     1.000000                             6.000000
# 75%               NaN     2.000000                            22.250000
# max               NaN   750.000000                           750.000000
#
#         Total Dead and Missing  Number of Survivors  Number of Females  \
# count              5987.000000           914.000000        1058.000000
# unique                     NaN                  NaN                NaN
# top                        NaN                  NaN                NaN
# freq                       NaN                  NaN                NaN
# mean                  5.664273            56.247265           1.984877
# std                  26.694092           134.411900           2.897452
# min                   0.000000             0.000000           0.000000
# 25%                   1.000000             4.000000           1.000000
# 50%                   1.000000            14.000000           1.000000
# 75%                   3.000000            52.000000           2.000000
# max                1022.000000          1950.000000          30.000000
#
#         Number of Males  Number of Children Cause of Death  \
# count       3286.000000          753.000000           5987
# unique              NaN                 NaN            266
# top                 NaN                 NaN       Drowning
# freq                NaN                 NaN           1151
# mean           1.842970            2.346614            NaN
# std            5.166482            9.458373            NaN
# min            0.000000            0.000000            NaN
# 25%            1.000000            1.000000            NaN
# 50%            1.000000            1.000000            NaN
# 75%            1.000000            2.000000            NaN
# max          135.000000          250.000000            NaN
#
#                           Location Description  \
# count                                     5977
# unique                                    3379
# top     Pima County jurisdiction, Arizona, USA
# freq                                       169
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#                                        Information Source  \
# count                                                5985
# unique                                               1658
# top     Mixed Migration Monitoring Mechanism Initiativ...
# freq                                                 1056
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                       Location Coordinates        Migration Route  \
# count                                 5986                   2931
# unique                                4124                     15
# top     31.965203600000, -113.011894500000  Central America to US
# freq                                   156                   1649
# mean                                   NaN                    NaN
# std                                    NaN                    NaN
# min                                    NaN                    NaN
# 25%                                    NaN                    NaN
# 50%                                    NaN                    NaN
# 75%                                    NaN                    NaN
# max                                    NaN                    NaN
#
#                                        URL UNSD Geographical Grouping  \
# count                                 3810                       5941
# unique                                2468                         20
# top     http://www.mixedmigration.org/4mi/           Northern America
# freq                                   806                       1310
# mean                                   NaN                        NaN
# std                                    NaN                        NaN
# min                                    NaN                        NaN
# 25%                                    NaN                        NaN
# 50%                                    NaN                        NaN
# 75%                                    NaN                        NaN
# max                                    NaN                        NaN
#
#         Source Quality
# count      5987.000000
# unique             NaN
# top                NaN
# freq               NaN
# mean          2.934525
# std           1.416122
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000

# %%
duplicateRows = df[df.duplicated()]
duplicateRows
# Out:
# Empty DataFrame
# Columns: [Web ID, Region of Incident, Reported Date, Reported Year, Reported Month, Number Dead, Minimum Estimated Number of Missing, Total Dead and Missing, Number of Survivors, Number of Females, Number of Males, Number of Children, Cause of Death, Location Description, Information Source, Location Coordinates, Migration Route, URL, UNSD Geographical Grouping, Source Quality]
# Index: []

# %%
import missingno as msno

msno.matrix(df, figsize=(14,7), fontsize=10, color=(0.5, 0.5, 1.0))
# Out:
# <Axes: >

# %%
data_missing = pd.DataFrame(index = df.columns.values)
data_missing['Null'] = df.isnull().sum().values
data_missing['Null percentage'] = (df.isna().sum() / len(df)).round(4) * 100
data_missing
# Out:
#                                      Null  Null percentage
# Web ID                                  0             0.00
# Region of Incident                      0             0.00
# Reported Date                           0             0.00
# Reported Year                           0             0.00
# Reported Month                          0             0.00
# Number Dead                           225             3.76
# Minimum Estimated Number of Missing  5411            90.38
# Total Dead and Missing                  0             0.00
# Number of Survivors                  5073            84.73
# Number of Females                    4929            82.33
# Number of Males                      2701            45.11
# Number of Children                   5234            87.42
# Cause of Death                          0             0.00
# Location Description                   10             0.17
# Information Source                      2             0.03
# Location Coordinates                    1             0.02
# Migration Route                      3056            51.04
# URL                                  2177            36.36
# UNSD Geographical Grouping             46             0.77
# Source Quality                          0             0.00
